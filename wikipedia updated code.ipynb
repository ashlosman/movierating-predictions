# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen
url = 'https://en.wikipedia.org/wiki/The_Batman_(film)'
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')

# %%
full_url_list = ['https://en.wikipedia.org/wiki/Glass_(2019_film)',
                'https://en.wikipedia.org/wiki/Captain_Marvel_(film)',
                'https://en.wikipedia.org/wiki/Us_(2019_film)',
                'https://en.wikipedia.org/wiki/John_Wick:_Chapter_3_%E2%80%93_Parabellum',
                'https://en.wikipedia.org/wiki/Frozen_II',
                'https://en.wikipedia.org/wiki/Marriage_Story',
                'https://en.wikipedia.org/wiki/Cats_(2019_film)',
                'https://en.wikipedia.org/wiki/It_Chapter_Two',
                'https://en.wikipedia.org/wiki/Sonic_the_Hedgehog_(film)',
                'https://en.wikipedia.org/wiki/Portrait_of_a_Lady_on_Fire',
                'https://en.wikipedia.org/wiki/Tenet_(film)',
                'https://en.wikipedia.org/wiki/Enola_Holmes_(film)',
                'https://en.wikipedia.org/wiki/Borat_Subsequent_Moviefilm',
                'https://en.wikipedia.org/wiki/The_Trial_of_the_Chicago_7',
                'https://en.wikipedia.org/wiki/The_King_of_Staten_Island',
                'https://en.wikipedia.org/wiki/Bad_Boys_for_Life',
                'https://en.wikipedia.org/wiki/Soul_(2020_film)',
                'https://en.wikipedia.org/wiki/Spider-Man:_Far_From_Home',
                'https://en.wikipedia.org/wiki/Toy_Story_4',
                'https://en.wikipedia.org/wiki/Yesterday_(2019_film)',
                'https://en.wikipedia.org/wiki/Avengers:_Endgame',
                'https://en.wikipedia.org/wiki/Once_Upon_a_Time_in_Hollywood',
                'https://en.wikipedia.org/wiki/The_Irishman',
                'https://en.wikipedia.org/wiki/A_Beautiful_Day_in_the_Neighborhood',
                'https://en.wikipedia.org/wiki/The_Two_Popes',
                'https://en.wikipedia.org/wiki/Harriet_(film)',
                'https://en.wikipedia.org/wiki/Black_Panther_(film)',
                'https://en.wikipedia.org/wiki/To_All_the_Boys_I%27ve_Loved_Before_(film)',
                'https://en.wikipedia.org/wiki/Ready_Player_One_(film)',
                'https://en.wikipedia.org/wiki/A_Quiet_Place',
                'https://en.wikipedia.org/wiki/Solo:_A_Star_Wars_Story',
                'https://en.wikipedia.org/wiki/Can_You_Keep_a_Secret%3F_(film)',
                'https://en.wikipedia.org/wiki/Tall_Girl',
                'https://en.wikipedia.org/wiki/The_Kissing_Booth',
                'https://en.wikipedia.org/wiki/Rocketman_(film)',
                'https://en.wikipedia.org/wiki/Hustlers_(film)',
                'https://en.wikipedia.org/wiki/Joker_(2019_film)',
                'https://en.wikipedia.org/wiki/Ocean%27s_8',
                'https://en.wikipedia.org/wiki/Deadpool_2',
                'https://en.wikipedia.org/wiki/Little_Women',
                'https://en.wikipedia.org/wiki/Eighth_Grade_(film)',
                'https://en.wikipedia.org/wiki/I_Feel_Pretty_(film)',
                'https://en.wikipedia.org/wiki/Blade_Runner_2049',
                'https://en.wikipedia.org/wiki/Spider-Man:_Homecoming',
                 'https://en.wikipedia.org/wiki/Call_Me_by_Your_Name_(film)',
                 'https://en.wikipedia.org/wiki/Dunkirk_(2017_film)',
                 'https://en.wikipedia.org/wiki/Thor:_Ragnarok',
                 'https://en.wikipedia.org/wiki/Baby_Driver',
                 'https://en.wikipedia.org/wiki/Get_Out',
                 'https://en.wikipedia.org/wiki/Justice_League_(film)',
                 'https://en.wikipedia.org/wiki/The_Greatest_Showman',
                 'https://en.wikipedia.org/wiki/Hitman%27s_Wife%27s_Bodyguard',
                 'https://en.wikipedia.org/wiki/Kingsman:_The_Golden_Circle',
                 'https://en.wikipedia.org/wiki/Wonder_Woman_(2017_film)',
                 'https://en.wikipedia.org/wiki/Jumanji:_Welcome_to_the_Jungle',
                 'https://en.wikipedia.org/wiki/Guardians_of_the_Galaxy_Vol._2',
                 'https://en.wikipedia.org/wiki/Logan_(film)',
                 'https://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_Dead_Men_Tell_No_Tales',
                 'https://en.wikipedia.org/wiki/Beauty_and_the_Beast_(2017_film)',
                 'https://en.wikipedia.org/wiki/Baywatch_(film)',
                 'https://en.wikipedia.org/wiki/Lady_Bird_(film)',
                 'https://en.wikipedia.org/wiki/Coco_(2017_film)',
                 'https://en.wikipedia.org/wiki/Transformers:_The_Last_Knight',
                 'https://en.wikipedia.org/wiki/The_Lego_Batman_Movie',
                 'https://en.wikipedia.org/wiki/Kong:_Skull_Island',
                 'https://en.wikipedia.org/wiki/XXX:_Return_of_Xander_Cage',
                 'https://en.wikipedia.org/wiki/Fantastic_Beasts_and_Where_to_Find_Them_(film)',
                 'https://en.wikipedia.org/wiki/Batman_v_Superman:_Dawn_of_Justice',
                 'https://en.wikipedia.org/wiki/Deadpool_(film)',
                 'https://en.wikipedia.org/wiki/Doctor_Strange_(2016_film)',
                 'https://en.wikipedia.org/wiki/Suicide_Squad_(film)']

ss = pd.DataFrame()
#for url in url_list:
html = urlopen(full_url_list[70]) 
soup = BeautifulSoup(html, 'html.parser')
tables = soup.find('tbody')
tr = [] #heading
td = [] #info
th = [] #

for t in range(len(tables)):
    tr.append(soup.find_all('tr')[t].get_text())
    td.append(soup.find_all('td')[t].get_text().replace("\n", ",")) 
    th.append(soup.find_all('th')[t].get_text())

#add to existing dataframe here
ss = ss.append(td, th)
ss.T
# Out:
#                           0           1           2   \
# 0  Theatrical release poster  David Ayer  David Ayer
#
#                                 3                               4   \
# 0  Characters fromDC Entertainment  ,Charles Roven,Richard Suckle,
#
#                                                   5               6   \
# 0  ,Will Smith,Jared Leto,Margot Robbie,Joel Kinn...  Roman Vasyanov
#
#             7             8   \
# 0  John Gilroy  Steven Price
#
#                                                   9                      10  \
# 0  ,Warner Bros. Pictures[1],RatPac-Dune Entertai...  Warner Bros. Pictures
#
#                                                   11              12  \
# 0  ,August 1, 2016 (2016-08-01) (Beacon Theatre),...  123 minutes[2]
#
#                  13       14               15                    16 17
# 0  United States[1]  English  $175 million[3]  $746.8 million[4][5]

# %%
dfs = [glass.T, cm.T, us.T, jw.T, frozen2.T, ms.T, cats.T,
       it.T,sonic.T, portrait.T, tenet.T, 
      enola.T, borat2.T, chicago7.T, statenisland.T,bbfl.T,
      soul.T, smffh.T, 
      toystory4.T, yesterday.T, avengers.T, ouatih.T, irishman.T,
       bditn.T, twopopes.T,
      harriet.T, bp.T,tatbilb.T, rp1.T, qp.T, solo.T, secret.T, 
       rocketman.T,
      hustlers.T, joker.T, oceans8.T,deadpool2.T,lw.T, egrade.T, 
       ifp.T, br2049.T, 
      smh.T, cmbyn.T, dunkirk.T, thor.T,  getout.T, justiceleague.T, 
       gshowman.T,
      hitman.T, kingsman_tgc.T, ww.T, jumanji.T, gotg2.T, logan.T,
       pirates.T, beauty.T,
       baywatch.T, ladybird.T, coco.T, transformers.T, lego.T, kong.T,
       xander.T, fb.T, 
       bvs.T, deadpool.T, ds.T, ss.T
      ]
all_movies_df = pd.concat(dfs)
display(all_movies_df)
# Out:
#                            0                          1   \
# 0   Theatrical release poster         M. Night Shyamalan
# 0   Theatrical release poster       Anna BodenRyan Fleck
# 0   Theatrical release poster               Jordan Peele
# 0   Theatrical release poster             Chad Stahelski
# 0   Theatrical release poster  ,Chris Buck,Jennifer Lee,
# ..                        ...                        ...
# 0   Theatrical release poster                David Yates
# 0   Theatrical release poster                Zack Snyder
# 0   Theatrical release poster                 Tim Miller
# 0   Theatrical release poster           Scott Derrickson
# 0   Theatrical release poster                 David Ayer
#
#                                                    2   \
# 0                                  M. Night Shyamalan
# 0     ,Anna Boden,Ryan Fleck,Geneva Robertson-Dworet,
# 0                                        Jordan Peele
# 0   ,Derek Kolstad,Shay Hatten,Chris Collins,Marc ...
# ...

# %%
all_movies_df.to_csv('additional_wiki.csv')

# %%
html = urlopen(full_url_list[70]) 
#html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')
awards=soup.find('table',{'class':"wikitable"})
    
    
df=pd.read_html(str(awards))
df=pd.DataFrame(df[0])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2h/xfb_97bn5lj9n6py7cp4kx_00000gn/T/ipykernel_6859/2034263007.py in <module>
#       5
#       6
# ----> 7 df=pd.read_html(str(awards))
#       8 df=pd.DataFrame(df[0])
#       9 print(df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
# ...

# %%
wiki = pd.read_csv('~/Desktop/stats 170b/wikipedia table.csv')

# %%
# general 
import pandas as pd 
import numpy as np 
from datetime import datetime

# stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# plotting
import seaborn as sns 
#import plotly.express as px
import matplotlib.pyplot as plt

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (10, 8)

# %%
sns.set(font_scale = 1.5)
sns.scatterplot(x='Budget', y = 'Box office', hue = 'Number Awards',data = wiki,s = 100)
#plt.legend('Number of Awards', loc="upper right", frameon=True, fontsize=10)
plt.xlabel('Budget for Film (in hundred millions)')
plt.ylabel('Box Office (in hundred millions)')
plt.title('Box Office vs Budget for Films')
# Out:
# Text(0.5, 1.0, 'Box Office vs Budget for Films')
