# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen
url = 'https://en.wikipedia.org/wiki/The_Batman_(film)'
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')

# general 
import pandas as pd 
import numpy as np 
from datetime import datetime

# stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# plotting
import seaborn as sns 
#import plotly.express as px
import matplotlib.pyplot as plt

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (10, 8)

# %%
#tables = soup.find('tbody')
print(soup.find_all('tbody')[0].get_text())
# Out:
# The BatmanTheatrical release posterDirected byMatt ReevesWritten by
# Matt Reeves
# Peter Craig
# Based onCharactersfrom DCProduced by
# Dylan Clark
# Matt Reeves
# Starring
# Robert Pattinson
# Zoë Kravitz
# Paul Dano
# Jeffrey Wright
# John Turturro
# Peter Sarsgaard
# Andy Serkis
# Colin Farrell
# CinematographyGreig FraserEdited by
# William Hoy
# Tyler Nelson
# Music byMichael GiacchinoProductioncompanies
# Warner Bros. Pictures[1]
# DC Films
# 6th & Idaho[1]
# Dylan Clark Productions[1]
# Distributed byWarner Bros. PicturesRelease dates
# March 1, 2022 (2022-03-01) (Lincoln Center)
# March 4, 2022 (2022-03-04) (United States)
# Running time176 minutes[2]CountryUnited States[1]LanguageEnglishBudget$185–200 million[3][4]Box office$736.7 million[5][6]

# %%
tables = soup.find('tbody')

ranks = []
rates = []
countries = []
for table in tables:
    rows = table.find_all('tr').
    #print(table)
    
    for row in rows:
        cells = row.find_all('td')
        print(cells)
        
        if len(cells) > 1:
            rank = cells[0]
            ranks.append((rank.text))
            
            country = cells[1]
            countries.append(country.text.strip())

# %%
for table in tables:
    tr = table.find_all('tr')[0].get_text()
    
    for row_info in tr:
        th = row_info.find_all('th')
        td = row_info.find_all('td')
        print(row_info)
        print(td)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2h/xfb_97bn5lj9n6py7cp4kx_00000gn/T/ipykernel_5032/3572290619.py in <module>
# ----> 1 for table in tables:
#       2     tr = table.find_all('tr')[0].get_text()
#       3
#       4     for row_info in tr:
#       5         th = row_info.find_all('th')
#
# NameError: name 'tables' is not defined

# %%
full_url_list = ['https://en.wikipedia.org/wiki/The_Batman_(film)','https://en.wikipedia.org/wiki/Eternals_(film)', 
            'https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home', 'https://en.wikipedia.org/wiki/Don%27t_Look_Up',
           'https://en.wikipedia.org/wiki/House_of_Gucci', 'https://en.wikipedia.org/wiki/Tick,_Tick..._Boom!_(film)',
           'https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)','https://en.wikipedia.org/wiki/He%27s_All_That',
           'https://en.wikipedia.org/wiki/In_the_Heights_(film)', 'https://en.wikipedia.org/wiki/Cruella_(film)',
           'https://en.wikipedia.org/wiki/Free_Guy', 'https://en.wikipedia.org/wiki/Luca_(2021_film)',
            'https://en.wikipedia.org/wiki/Encanto_(film)','https://en.wikipedia.org/wiki/Spencer_(film)', 
            'https://en.wikipedia.org/wiki/Belfast_(film)', 'https://en.wikipedia.org/wiki/The_King%27s_Man', 
            'https://en.wikipedia.org/wiki/Shang-Chi_and_the_Legend_of_the_Ten_Rings', 'https://en.wikipedia.org/wiki/Black_Widow_(2021_film)',
             'https://en.wikipedia.org/wiki/Last_Night_in_Soho', 'https://en.wikipedia.org/wiki/Turning_Red', 
             'https://en.wikipedia.org/wiki/The_Card_Counter', 'https://en.wikipedia.org/wiki/Dear_Evan_Hansen_(film)', 
             'https://en.wikipedia.org/wiki/No_Time_to_Die', 'https://en.wikipedia.org/wiki/F9_(film)', 
             'https://en.wikipedia.org/wiki/Raya_and_the_Last_Dragon', 'https://en.wikipedia.org/wiki/Jungle_Cruise_(film)', 
             'https://en.wikipedia.org/wiki/The_Matrix_Resurrections', 'https://en.wikipedia.org/wiki/Dune_(2021_film)', 
             'https://en.wikipedia.org/wiki/Venom:_Let_There_Be_Carnage', 'https://en.wikipedia.org/wiki/Morbius_(film)']


html = urlopen(full_url_list[29]) 
soup = BeautifulSoup(html, 'html.parser')
tables = soup.find('tbody')
tr = []
td = []
th = []
for t in range(len(tables)):
    tr.append(soup.find_all('tr')[t].get_text())
    td.append(soup.find_all('td')[t].get_text().replace("\n", ",")) 
    th.append(soup.find_all('th')[t].get_text())

# %%
df = pd.DataFrame(td, th)
df.T
# Out:
#                      Morbius      Directed by                 Written by  \
# 0  Theatrical release poster  Daniel Espinosa  Matt SazamaBurk Sharpless
#
#         Based on                           Produced by  \
# 0  Marvel Comics  ,Avi Arad,Matt Tolmach,Lucas Foster,
#
#                                             Starring Cinematography  \
# 0  ,Jared Leto,Matt Smith,Adria Arjona,Jared Harr...    Oliver Wood
#
#           Edited by      Music by  \
# 0  Pietro Scalia[1]  Jon Ekstrand
#
#                                  Productioncompanies           Distributed by  \
# 0  ,Columbia Pictures,Marvel Entertainment,Arad P...  Sony Pictures Releasing
#
#                                        Release dates    Running time  \
# 0  ,March 10, 2022 (2022-03-10) (Plaza Carso),Apr...  104 minutes[2]
#
#          Country Language             Budget            Box office  \
# 0  United States  English  $75–83 million[3]  $129.7 million[4][5]
#
# ...

# %%
th
# Out:
# ['The Batman',
#  'Directed by',
#  'Written by',
#  'Based on',
#  'Produced by',
#  'Starring',
#  'Cinematography',
#  'Edited by',
#  'Music by',
#  'Productioncompanies',
#  'Distributed by',
#  'Release dates',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Award\n']

# %%
full_url_list = [
             'https://en.wikipedia.org/wiki/Raya_and_the_Last_Dragon', 'https://en.wikipedia.org/wiki/Jungle_Cruise_(film)', 
             'https://en.wikipedia.org/wiki/The_Matrix_Resurrections', 'https://en.wikipedia.org/wiki/Dune_(2021_film)', 
             'https://en.wikipedia.org/wiki/Venom:_Let_There_Be_Carnage', 'https://en.wikipedia.org/wiki/Morbius_(film)']

url_list = ['https://en.wikipedia.org/wiki/Eternals_(film)']

eternals = pd.DataFrame()
for url in url_list:
    html = urlopen(url) 
    soup = BeautifulSoup(html, 'html.parser')
    tables = soup.find('tbody')
    tr = [] #heading
    td = [] #info
    th = [] #
  
    for t in range(len(tables)):
        tr.append(soup.find_all('tr')[t].get_text())
        td.append(soup.find_all('td')[t].get_text().replace("\n", ",")) 
        th.append(soup.find_all('th')[t].get_text())
 
    #add to existing dataframe here
eternals = eternals.append(td, th)
eternals.T
    #movie_df[url] = td
# Out:
#                           0           1   \
# 0  Theatrical release poster  Chloé Zhao
#
#                                                   2                       3   \
# 0  ,Chloé Zhao[N 1],Patrick Burleigh,Ryan Firpo,K...  ,Ryan Firpo,Kaz Firpo,
#
#                       4                         5   \
# 0  Eternalsby Jack Kirby  ,Kevin Feige,Nate Moore,
#
#                                                   6          7   \
# 0  ,Gemma Chan,Richard Madden,Kumail Nanjiani,Lia...  Ben Davis
#
#                             8              9               10  \
# 0  ,Craig Wood,Dylan Tichenor,  Ramin Djawadi  Marvel Studios
#
#                                    11  \
# 0  Walt Disney StudiosMotion Pictures
#
#                                                   12              13  \
# 0  ,October 18, 2021 (2021-10-18) (Dolby Theatre)...  156 minutes[3]
#
#               14       15               16                    17 18
# ...

# %%
df = pd.DataFrame()
full_url_list = ['https://en.wikipedia.org/wiki/The_Batman_(film)','https://en.wikipedia.org/wiki/Eternals_(film)', 
            'https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home', 'https://en.wikipedia.org/wiki/Don%27t_Look_Up',
           'https://en.wikipedia.org/wiki/House_of_Gucci', 'https://en.wikipedia.org/wiki/Tick,_Tick..._Boom!_(film)',
           'https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)','https://en.wikipedia.org/wiki/He%27s_All_That',
           'https://en.wikipedia.org/wiki/In_the_Heights_(film)', 'https://en.wikipedia.org/wiki/Cruella_(film)',
           'https://en.wikipedia.org/wiki/Free_Guy', 'https://en.wikipedia.org/wiki/Luca_(2021_film)',
            'https://en.wikipedia.org/wiki/Encanto_(film)','https://en.wikipedia.org/wiki/Spencer_(film)', 
            'https://en.wikipedia.org/wiki/Belfast_(film)', 'https://en.wikipedia.org/wiki/The_King%27s_Man', 
            'https://en.wikipedia.org/wiki/Shang-Chi_and_the_Legend_of_the_Ten_Rings', 'https://en.wikipedia.org/wiki/Black_Widow_(2021_film)',
             'https://en.wikipedia.org/wiki/Last_Night_in_Soho', 'https://en.wikipedia.org/wiki/Turning_Red', 
             'https://en.wikipedia.org/wiki/The_Card_Counter', 'https://en.wikipedia.org/wiki/Dear_Evan_Hansen_(film)', 
             'https://en.wikipedia.org/wiki/No_Time_to_Die', 'https://en.wikipedia.org/wiki/F9_(film)', 
             'https://en.wikipedia.org/wiki/Raya_and_the_Last_Dragon', 'https://en.wikipedia.org/wiki/Jungle_Cruise_(film)', 
             'https://en.wikipedia.org/wiki/The_Matrix_Resurrections', 'https://en.wikipedia.org/wiki/Dune_(2021_film)', 
             'https://en.wikipedia.org/wiki/Venom:_Let_There_Be_Carnage', 'https://en.wikipedia.org/wiki/Morbius_(film)']


html = urlopen(full_url_list[0]) 
#html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')
awards=soup.find('table',{'class':"wikitable"})
    
    
df=pd.read_html(str(awards))
df=pd.DataFrame(df[0])
print(df)
# Out:
#                    Award Date of ceremony                    Category  \
# 0  Golden Trailer Awards    July 22, 2021                 Best Teaser
# 1  Golden Trailer Awards    July 22, 2021  Best Motion/Title Graphics
# 2  Golden Trailer Awards    July 22, 2021          Best Sound Editing
#
#             Recipient(s)     Result   Ref.
# 0  Statement Advertising  Nominated  [347]
# 1      Devastudios, Inc.  Nominated  [347]
# 2  Statement Advertising  Nominated  [347]

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/The_Batman_(film)
"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
row
# Out:
# []

# %%
eternals.T
# Out:
#                           0           1   \
# 0  Theatrical release poster  Chloé Zhao
#
#                                                   2                       3   \
# 0  ,Chloé Zhao[N 1],Patrick Burleigh,Ryan Firpo,K...  ,Ryan Firpo,Kaz Firpo,
#
#                       4                         5   \
# 0  Eternalsby Jack Kirby  ,Kevin Feige,Nate Moore,
#
#                                                   6          7   \
# 0  ,Gemma Chan,Richard Madden,Kumail Nanjiani,Lia...  Ben Davis
#
#                             8              9               10  \
# 0  ,Craig Wood,Dylan Tichenor,  Ramin Djawadi  Marvel Studios
#
#                                    11  \
# 0  Walt Disney StudiosMotion Pictures
#
#                                                   12              13  \
# 0  ,October 18, 2021 (2021-10-18) (Dolby Theatre)...  156 minutes[3]
#
#               14       15               16                    17 18
# ...

# %%
dfs = [eternals.T, thebatman.T, spiderman_nwh.T,dontlookup.T, gucci.T,ticktickboom.T, 
       westsidestory.T, hesallthat.T, intheheights.T,cruella.T, freeguy.T, luca.T, encanto.T,
       spencer.T,belfast.T, thekingsman.T, shangchi.T, blackwidow.T, soho.T, turningred.T,
       cardcounter.T, dearevanhansen.T, nttd.T, f9.T, raya.T, junglecruise.T, matrix.T, 
       dune.T, venom.T, morbius.T]
all_movies_df = pd.concat(dfs)
display(all_movies_df)
# Out:
#                            0                                1   \
# 0   Theatrical release poster                       Chloé Zhao
# 0   Theatrical release poster                      Matt Reeves
# 0   Theatrical release poster                        Jon Watts
# 0              Release poster                       Adam McKay
# 0   Theatrical release poster                     Ridley Scott
# 0              Release poster               Lin-Manuel Miranda
# 0   Theatrical release poster                 Steven Spielberg
# 0     Official release poster                      Mark Waters
# 0   Theatrical release poster                       Jon M. Chu
# 0              Release poster                  Craig Gillespie
# 0   Theatrical release poster                       Shawn Levy
# 0   Theatrical release poster        ,Jared Bush,Byron Howard,
# 0   Theatrical release poster                    Pablo Larraín
# 0   Theatrical release poster                  Kenneth Branagh
# ...

# %%
all_movies_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2h/xfb_97bn5lj9n6py7cp4kx_00000gn/T/ipykernel_5032/461580841.py in <module>
# ----> 1 all_movies_df
#
# NameError: name 'all_movies_df' is not defined

# %%
#df.to_csv("presidents.csv")
all_movies_df.to_csv("all_movies.csv")

# %%
full_url_list = ['https://en.wikipedia.org/wiki/The_Batman_(film)','https://en.wikipedia.org/wiki/Eternals_(film)', 
            'https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home', 'https://en.wikipedia.org/wiki/Don%27t_Look_Up',
           'https://en.wikipedia.org/wiki/House_of_Gucci', 'https://en.wikipedia.org/wiki/Tick,_Tick..._Boom!_(film)',
           'https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)','https://en.wikipedia.org/wiki/He%27s_All_That',
           'https://en.wikipedia.org/wiki/In_the_Heights_(film)', 'https://en.wikipedia.org/wiki/Cruella_(film)',
           'https://en.wikipedia.org/wiki/Free_Guy', 'https://en.wikipedia.org/wiki/Luca_(2021_film)',
            'https://en.wikipedia.org/wiki/Encanto_(film)','https://en.wikipedia.org/wiki/Spencer_(film)', 
            'https://en.wikipedia.org/wiki/Belfast_(film)', 'https://en.wikipedia.org/wiki/The_King%27s_Man', 
            'https://en.wikipedia.org/wiki/Shang-Chi_and_the_Legend_of_the_Ten_Rings', 'https://en.wikipedia.org/wiki/Black_Widow_(2021_film)',
             'https://en.wikipedia.org/wiki/Last_Night_in_Soho', 'https://en.wikipedia.org/wiki/Turning_Red', 
             'https://en.wikipedia.org/wiki/The_Card_Counter', 'https://en.wikipedia.org/wiki/Dear_Evan_Hansen_(film)', 
             'https://en.wikipedia.org/wiki/No_Time_to_Die', 'https://en.wikipedia.org/wiki/F9_(film)', 
             'https://en.wikipedia.org/wiki/Raya_and_the_Last_Dragon', 'https://en.wikipedia.org/wiki/Jungle_Cruise_(film)', 
             'https://en.wikipedia.org/wiki/The_Matrix_Resurrections', 'https://en.wikipedia.org/wiki/Dune_(2021_film)', 
             'https://en.wikipedia.org/wiki/Venom:_Let_There_Be_Carnage', 'https://en.wikipedia.org/wiki/Morbius_(film)']



url_list = ['https://en.wikipedia.org/wiki/The_Batman_(film)','https://en.wikipedia.org/wiki/Eternals_(film)', 
            'https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home', 'https://en.wikipedia.org/wiki/Don%27t_Look_Up',
           'https://en.wikipedia.org/wiki/House_of_Gucci', 'https://en.wikipedia.org/wiki/Tick,_Tick..._Boom!_(film)',
           'https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)','https://en.wikipedia.org/wiki/He%27s_All_That',
           'https://en.wikipedia.org/wiki/In_the_Heights_(film)', 'https://en.wikipedia.org/wiki/Cruella_(film)']

# %%
url_list = ['https://en.wikipedia.org/wiki/The_Batman_(film)','https://en.wikipedia.org/wiki/Eternals_(film)', 
            'https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home', 'https://en.wikipedia.org/wiki/Don%27t_Look_Up',
           'https://en.wikipedia.org/wiki/House_of_Gucci', 'https://en.wikipedia.org/wiki/Tick,_Tick..._Boom!_(film)',
           'https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)','https://en.wikipedia.org/wiki/He%27s_All_That',
           'https://en.wikipedia.org/wiki/In_the_Heights_(film)', 'https://en.wikipedia.org/wiki/Cruella_(film)']
movie_df = pd.DataFrame()
for url in url_list:
    html = urlopen(url) 
    soup = BeautifulSoup(html, 'html.parser')
    tables = soup.find('tbody')
    tr = [] #heading
    td = () #info
    th = [] #columns
    tabledict = {}
  
    for t in range(len(tables)):
        tr.append(soup.find_all('tr')[t].get_text())
        #td.append(soup.find_all('td')[t].get_text()) 
        th.append(soup.find_all('th')[t].get_text())
      
        td_list = list(td)
        td_list.append(soup.find_all('td')[t].get_text())
        td = tuple(td_list)

        #tabledict[th] = td
        #print(tabledict)
        
        #tabledict[(soup.find_all('th')[t].get_text())] = td
        #print(tabledict)

# %%
#summary_dict = {}

full_url_list = ['https://en.wikipedia.org/wiki/The_Batman_(film)','https://en.wikipedia.org/wiki/Eternals_(film)', 
            'https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home', 'https://en.wikipedia.org/wiki/Don%27t_Look_Up',
           'https://en.wikipedia.org/wiki/House_of_Gucci', 'https://en.wikipedia.org/wiki/Tick,_Tick..._Boom!_(film)',
           'https://en.wikipedia.org/wiki/West_Side_Story_(2021_film)','https://en.wikipedia.org/wiki/He%27s_All_That',
           'https://en.wikipedia.org/wiki/In_the_Heights_(film)', 'https://en.wikipedia.org/wiki/Cruella_(film)',
           'https://en.wikipedia.org/wiki/Free_Guy', 'https://en.wikipedia.org/wiki/Luca_(2021_film)',
            'https://en.wikipedia.org/wiki/Encanto_(film)','https://en.wikipedia.org/wiki/Spencer_(film)', 
            'https://en.wikipedia.org/wiki/Belfast_(film)', 'https://en.wikipedia.org/wiki/The_King%27s_Man', 
            'https://en.wikipedia.org/wiki/Shang-Chi_and_the_Legend_of_the_Ten_Rings', 'https://en.wikipedia.org/wiki/Black_Widow_(2021_film)',
             'https://en.wikipedia.org/wiki/Last_Night_in_Soho', 'https://en.wikipedia.org/wiki/Turning_Red', 
             'https://en.wikipedia.org/wiki/The_Card_Counter', 'https://en.wikipedia.org/wiki/Dear_Evan_Hansen_(film)', 
             'https://en.wikipedia.org/wiki/No_Time_to_Die', 'https://en.wikipedia.org/wiki/F9_(film)', 
             'https://en.wikipedia.org/wiki/Raya_and_the_Last_Dragon', 'https://en.wikipedia.org/wiki/Jungle_Cruise_(film)', 
             'https://en.wikipedia.org/wiki/The_Matrix_Resurrections', 'https://en.wikipedia.org/wiki/Dune_(2021_film)', 
             'https://en.wikipedia.org/wiki/Venom:_Let_There_Be_Carnage', 'https://en.wikipedia.org/wiki/Morbius_(film)']

morbius_par = pd.DataFrame()
html = urlopen(full_url_list[29]) 
soup = BeautifulSoup(html, 'html.parser')
url_info = {}
headlines = soup.find_all('h2')
for i in headlines:
    p_list = []
    for paragraph in range(len(headlines)):
        p_list.append((soup.find_all('p')[paragraph].get_text()))

morbius_par = morbius_par.append(p_list, ignore_index = True)

# %%
morbius_par.T
# Out:
#    0                                                  1   \
# 0  \n  Morbius is a 2022 American superhero film base...
#
#                                                   2   \
# 0  After announcing plans for a new shared univer...
#
#                                                   3   \
# 0  Morbius premiered at the Plaza Carso in Mexico...
#
#                                                   4   \
# 0  At a hospital in Greece, 10-year-old Michael M...
#
#                                                   5   \
# 0  25 years later, Morbius publicly declines a No...
#
#                                                   6   \
# 0  Morbius returns to New York and discovers he n...
#
#                                                   7   \
# 0  Morbius meets Bancroft to explain what Milo ha...
#
#                                                   8   \
# 0  In a mid-credits scene, Adrian Toomes finds hi...
#
#                                                   9   \
# ...

# %%
dfs = [eternals_par.T, thebatman_par.T, spiderman_nwh_par.T,dontlookup_par.T, gucci_par.T,ticktickboom_par.T, 
       westsidestory_par.T, hesallthat_par.T, intheheights_par.T,cruella_par.T, freeguy_par.T, luca_par.T,
       encanto_par.T,spencer_par.T,belfast_par.T, thekingsman_par.T, shangchi_par.T, blackwidow_par.T, 
       soho_par.T, turningred_par.T, cardcounter_par.T, dearevanhansen_par.T, nttd_par.T, f9_par.T, raya_par.T, 
       junglecruise_par.T, matrix_par.T, dune_par.T, venom_par.T, morbius_par.T]
movie_paragraphs = pd.concat(dfs)
display(movie_paragraphs)
# Out:
#    0                                                  1   \
# 0  \n  Eternals is a 2021 American superhero film bas...
# 0  \n  The Batman is a 2022 American superhero film b...
# 0  \n  Spider-Man: No Way Home is a 2021 American sup...
# 0  \n  Don't Look Up is a 2021 American apocalyptic b...
# 0  \n  House of Gucci is a 2021 American biographical...
# 0  \n  Tick, Tick... Boom! (also stylized as tick, ti...
# 0  \n  West Side Story is a 2021 American musical rom...
# 0  \n  He's All That is a 2021 American teen romantic...
# 0  \n  In the Heights is a 2021 American musical dram...
# 0  \n  Cruella is a 2021 American crime comedy film b...
# 0  \n  Free Guy is a 2021 American action comedy film...
# 0  \n  Luca is a 2021 American computer-animated comi...
# 0  \n                                                 \n
# 0  \n  Spencer is a 2021 historical fiction[7][8] psy...
# 0  \n  Belfast is a 2021 British coming-of-age drama ...
# ...

# %%
movie_paragraphs.to_csv("wiki_movie_paragraphs.csv")

# %%
ax = sns.barplot(x="Number Awards", y="Box office", hue="Movie", data=all_movies_df)

# %%
all_movies_df = pd.read_csv('~/Desktop/stats 170b/wikipedia table.csv')

# %%
bar_plot1 = sns.barplot(x='Movie', y='Box office', data=all_movies_df[0:5], label="Box office", color="red")
bar_plot2 = sns.barplot(x='Movie', y='Budget', data=all_movies_df[0:5], label="Budget", color="green")
fontsize = 20
plt.legend(loc="upper right", frameon=True, fontsize=fontsize)
plt.show()

# %%
sns.set()
#flights = sns.load_dataset("flights")
#all_movies_df = all_movies_df.pivot("Movie", "Budget", "Box office","Number Awards")
ax = sns.heatmap(all_movies_df)
plt.title("Heatmap Flight Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2h/xfb_97bn5lj9n6py7cp4kx_00000gn/T/ipykernel_5032/2379000448.py in <module>
#       1 sns.set()
#       2 #flights = sns.load_dataset("flights")
# ----> 3 all_movies_df = all_movies_df.pivot("Movie", "Budget", "Box office","Number Awards")
#       4 ax = sns.heatmap(all_movies_df)
#       5 plt.title("Heatmap Flight Data")
#
# TypeError: pivot() takes from 1 to 4 positional arguments but 5 were given

# %%
sns.set(font_scale = 1.5)
sns.scatterplot(x='Budget', y = 'Box office', hue = 'Number Awards',data = all_movies_df,s = 100)
#plt.legend('Number of Awards', loc="upper right", frameon=True, fontsize=10)
plt.xlabel('Budget for Film (in hundred millions)')
plt.ylabel('Box Office (in hundred millions)')
plt.title('Box Office vs Budget for Films')
# Out:
# Text(0.5, 1.0, 'Box Office vs Budget for Films')

# %%
all_movies_df
# Out:
#                           Movie       Budget    Box office  \
# 0                      Eternals  200000000.0  4.021000e+08
# 1                    The Batman  200000000.0  7.378000e+08
# 2       Spider-Man: No Way Home  200000000.0  1.892000e+09
# 3                 Don't Look Up   75000000.0  7.918630e+05
# 4                House of Gucci   75000000.0  1.567000e+08
# 5              Tick, Tick… Boom          NaN  1.155850e+05
# 6               West Side Story  100000000.0  7.570000e+07
# 7                 He's All That   20000000.0           NaN
# 8                In the Heights   55000000.0  4.400000e+07
# 9                       Cruella  200000000.0  2.335000e+08
# 10                     Free Guy  125000000.0  3.315000e+08
# 11                         Luca          NaN  4.980000e+07
# 12                      Encanto  150000000.0  2.538000e+08
# 13                      Spencer   18000000.0  2.340000e+07
# 14                      Belfast          NaN  4.700000e+07
# ...
